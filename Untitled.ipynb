# %%
# !pip install rdkit
# Out:
# ...
#   Using cached rdkit-2024.3.6-cp310-cp310-win_amd64.whl.metadata (4.0 kB)
# ...
#    ---------------------------------------- 0.0/21.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/21.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/21.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/21.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/21.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/21.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/21.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/21.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/21.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/21.7 MB 78.6 kB/s eta 0:04:37
#    ---------------------------------------- 0.0/21.7 MB 78.6 kB/s eta 0:04:37
#    ---------------------------------------- 0.1/21.7 MB 204.8 kB/s eta 0:01:46
# ...

# %%
import rdkit

# %%
from chembl_webresource_client . new_client import new_client
import pandas as pd
